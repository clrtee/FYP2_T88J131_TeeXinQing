# %%
import pandas as pd

df = pd.read_csv("../results/casas_fedavg_r50.csv") 
df
# Out:
#     round      loss  accuracy        f1
# 0       1  2.211191  0.197848  0.033034
# 1       2  2.205874  0.179287  0.030928
# 2       3  2.738888  0.059424  0.037118
# 3       4  2.547752  0.144038  0.098385
# 4       5  1.874112  0.500663  0.261423
# 5       6  1.942865  0.501443  0.313030
# 6       7  1.524289  0.588864  0.365846
# 7       8  0.892700  0.675739  0.421736
# 8       9  1.227554  0.625127  0.390764
# 9      10  1.087878  0.655151  0.414179
# 10     11  1.288865  0.657412  0.402882
# 11     12  0.936646  0.709116  0.440959
# 12     13  0.867317  0.756141  0.482410
# 13     14  0.876723  0.742962  0.479430
# 14     15  0.871230  0.755361  0.484647
# 15     16  0.849912  0.812524  0.536937
# 16     17  0.863454  0.793340  0.518900
# 17     18  0.698438  0.820557  0.537638
# 18     19  0.776147  0.823598  0.564834
# 19     20  0.799966  0.786087  0.528182
# 20     21  0.716495  0.829837  0.577116
# 21     22  0.729106  0.812524  0.589681
# 22     23  0.776428  0.839429  0.572660
# 23     24  0.732670  0.846760  0.569347
# 24     25  0.813302  0.838025  0.567123
# 25     26  0.697204  0.860797  0.584509
# 26     27  0.690898  0.860017  0.603788
# 27     28  0.674364  0.861421  0.598975
# 28     29  0.826974  0.789987  0.583105
# 29     30  0.668588  0.863682  0.634428
# 30     31  0.648983  0.867660  0.622937
# 31     32  0.762684  0.830851  0.592206
# 32     33  0.736148  0.839429  0.579758
# 33     34  0.623703  0.863916  0.641891
# 34     35  0.763917  0.860251  0.602067
# 35     36  0.722758  0.863916  0.640374
# 36     37  0.659540  0.868595  0.612514
# 37     38  0.906510  0.775326  0.580965
# 38     39  1.874136  0.724168  0.525736
# 39     40  0.649347  0.863059  0.669727
# 40     41  0.620804  0.875926  0.663796
# 41     42  0.641445  0.878032  0.646308
# 42     43  0.800218  0.866958  0.608719
# 43     44  1.343625  0.743040  0.524025
# 44     45  0.678607  0.861499  0.641876
# 45     46  0.965500  0.788115  0.515081
# 46     47  0.596409  0.871871  0.673420
# 47     48  0.620576  0.870233  0.676645
# 48     49  0.652794  0.870779  0.675076
# 49     50  0.660860  0.865944  0.652905

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(df["round"], df["accuracy"])
plt.xlabel("Communication Round")
plt.ylabel("Accuracy")
plt.title("FedAvg on CASAS (α = 0.1)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure()
plt.plot(df["round"], df["f1"])
plt.xlabel("Communication Round")
plt.ylabel("F1-score")
plt.title("FedAvg on CASAS (α = 0.1)")
plt.grid(True)
plt.tight_layout()
plt.show()
