# %%
import pandas as pd

df = pd.read_csv("../results/casas_scaffold_r50.csv") 
df
# Out:
#     round      loss  accuracy        f1
# 0       1  2.111677  0.336271  0.050330
# 1       2  1.949818  0.336271  0.050330
# 2       3  1.836968  0.336271  0.050330
# 3       4  1.780103  0.336271  0.050330
# 4       5  1.758418  0.336271  0.050330
# 5       6  1.750885  0.336271  0.050330
# 6       7  1.746573  0.336271  0.050330
# 7       8  1.744019  0.336271  0.050330
# 8       9  1.756609  0.336271  0.050330
# 9      10  1.965353  0.197848  0.033034
# 10     11  3.059389  0.336271  0.050330
# 11     12  3.129597  0.197848  0.033034
# 12     13  2.445352  0.179989  0.030507
# 13     14  2.412102  0.179989  0.030507
# 14     15  3.568693  0.197848  0.033034
# 15     16  3.289841  0.336271  0.050330
# 16     17  3.191907  0.179989  0.030507
# 17     18  1.943068  0.336271  0.050330
# 18     19  2.302931  0.336271  0.050330
# 19     20  2.831316  0.336271  0.050330
# 20     21  2.916779  0.336271  0.050330
# 21     22  2.445485  0.179989  0.030507
# 22     23  2.227572  0.180223  0.031022
# 23     24  2.063035  0.179989  0.030529
# 24     25  2.482887  0.179989  0.030507
# 25     26  2.351968  0.336271  0.050330
# 26     27  2.494565  0.336271  0.053304
# 27     28  1.734752  0.451142  0.117706
# 28     29  2.296088  0.185526  0.055188
# 29     30  2.611849  0.336271  0.050330
# 30     31  1.689489  0.442564  0.117306
# 31     32  1.997429  0.203930  0.037411
# 32     33  3.350167  0.336271  0.052375
# 33     34  2.111901  0.426811  0.113637
# 34     35  3.779006  0.197848  0.033034
# 35     36  2.354678  0.335569  0.057204
# 36     37  2.053899  0.352414  0.098201
# 37     38  1.680217  0.475864  0.121909
# 38     39  2.254234  0.440147  0.118102
# 39     40  2.706429  0.362084  0.101047
# 40     41  2.533702  0.200733  0.035541
# 41     42  4.006650  0.197848  0.033034
# 42     43  2.758343  0.197848  0.033034
# 43     44  1.904727  0.349918  0.073317
# 44     45  1.750769  0.493254  0.128764
# 45     46  2.590546  0.338064  0.067466
# 46     47  2.244442  0.306325  0.110450
# 47     48  3.783581  0.329876  0.057198
# 48     49  3.327865  0.343523  0.074975
# 49     50  1.297544  0.611557  0.241054

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(df["round"], df["accuracy"])
plt.xlabel("Communication Round")
plt.ylabel("Accuracy")
plt.title("Scaffold on CASAS (α = 0.1)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure()
plt.plot(df["round"], df["f1"])
plt.xlabel("Communication Round")
plt.ylabel("F1-score")
plt.title("FedProx on CASAS (α = 0.1)")
plt.grid(True)
plt.tight_layout()
plt.show()
