# %%
import sys
print(sys.executable)
# Out:
# /home/clara/Research/fyp_fl_smart_home/.venv/bin/python

# %%
import os

print(os.path.exists("../data/uci_har/UCI HAR Dataset/train/Inertial Signals/body_acc_x_train.txt"))
print(os.path.exists("../data/casas_aruba/aruba.csv"))
# Out:
# True
# True
